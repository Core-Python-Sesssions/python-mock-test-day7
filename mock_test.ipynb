# %% [markdown]
# # 🧪 Python Mock Test – Day 7
#
# ### Section 1: Data Types and Input/Output
# Write Python code to:
# - Take user input
# - Print the type of each input
# - Convert input to int/float where applicable

# %%
# Your code here

# %% [markdown]
# ### Section 2: Conditional Statements
# Write a program to check if a number is positive, negative, or zero.

# %%
# Your code here

# %% [markdown]
# ### Section 3: Loops
# Write a program to print all even numbers between 1 and 20.

# %%
# Your code here

# %% [markdown]
# ### Section 4: Functions
# Define a function that takes 2 arguments and returns their product.

# %%
# Your code here

# %% [markdown]
# ### Section 5: String Operations
# Take a string input from the user and:
# - Convert to uppercase
# - Count vowels
# - Reverse the string

# %%
# Your code here
